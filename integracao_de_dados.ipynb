# %% [markdown]
# Observamos que um processo de integração e análise de dados depende de um passo anterior que é justamente onde entra o ETL. O ETL, bem como o ELT e a ingestão de dados, visa preparar o conjunto de dados para que se possa realizar posteriores trabalhos.
#
# Baseado no conteúdo estudado, um fluxo considerando duas fontes distintas de dados levando em conta as seguintes restrições:
#
# Serão considerados dois tipos de fontes diferentes:
#
# - A primeira será o arquivo CSV.
#
# - A segunda será o arquivo de texto contendo um dicionário de termos.
#
# O fluxo deverá compreender as seguintes etapas:
#
# - Carregar os dados do CSV.
#
# - Carregar dados do arquivo texto.
#
# - Associar cada termo contido no arquivo texto com a coluna “Categoria” do arquivo CSV.
#
# - Formatar os dados da coluna “Valor” para ser exibido em formato monetário. Exemplo: “10.0” será exibido como “R$ 10,00”.
#
# - Escrever a saída deste processo em um arquivo CSV chamado “Resultado.csv”.

# %%
import pandas as pd

# %%
# carregando os dados
df = pd.read_csv('Dados.csv', sep=';')
df.head()
# Out:
#                                  Produto     Categoria    Valor  \
# 0    Alisha Solid Women's Cycling Shorts      Clothing    999.0
# 1    FabHomeDecor Fabric Double Sofa Bed     Furniture  32157.0
# 2                             AW Bellies      Footwear    999.0
# 3    Alisha Solid Women's Cycling Shorts      Clothing    699.0
# 4  Sicons All Purpose Arnica Dog Shampoo  Pet Supplies    220.0
#
#                                            Descricao         Marca
# 0  Key Features of Alisha Solid Women's Cycling S...        Alisha
# 1  FabHomeDecor Fabric Double Sofa Bed (Finish Co...  FabHomeDecor
# 2  Key Features of AW Bellies Sandals Wedges Heel...            AW
# 3  Key Features of Alisha Solid Women's Cycling S...        Alisha
# 4  Specifications of Sicons All Purpose Arnica Do...        Sicons

# %%
# importando os termos em txt
# cada termo fica em um índice da lista.

with open (r"Dicionario.txt", "r", encoding= 'utf-8') as arq:
    termos = []
    for linhas in arq.readlines():
        termos.append(linhas.strip())

# %%
# Associando termo ao tipo da colua categoria
for linha in df.index:
    for item in termos:
        if item.startswith(df.loc[linha, "Categoria"]):
            df.loc[linha, 'Termo'] = item

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4557 entries, 0 to 4556
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Produto    4557 non-null   object
#  1   Categoria  4557 non-null   object
#  2   Valor      4547 non-null   float64
#  3   Descricao  4556 non-null   object
#  4   Marca      3452 non-null   object
#  5   Termo      4557 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 213.7+ KB

# %%
# função para formatar valor

def formatar(valor):
    return "R$:{:.2f}".format(valor).replace('.', ',')

# %%
# formatando a coluna valor
df['Valor'] = df['Valor'].apply(formatar)

df
# Out:
#                                                 Produto  \
# 0                   Alisha Solid Women's Cycling Shorts
# 1                   FabHomeDecor Fabric Double Sofa Bed
# 2                                            AW Bellies
# 3                   Alisha Solid Women's Cycling Shorts
# 4                 Sicons All Purpose Arnica Dog Shampoo
# ...                                                 ...
# 4552  Krg Enterprises Traditional Chirag Showpiece  ...
# 4553                         Vinnis Bella Bone Necklace
# 4554  Rajo Raja The Buddha Of Music Artpiece Showpie...
# 4555  Zakaah Jewels Amazing Quartz Sterling Silver P...
# 4556              VR Designers Plastic; Copper Necklace
#
#                        Categoria        Valor  \
# 0                       Clothing    R$:999,00
# 1                      Furniture  R$:32157,00
# 2                       Footwear    R$:999,00
# 3                       Clothing    R$:699,00
# 4                   Pet Supplies    R$:220,00
# ...                          ...          ...
# 4552  Home Decor & Festive Needs   R$:1499,00
# 4553                   Jewellery    R$:650,00
# 4554  Home Decor & Festive Needs   R$:4499,00
# 4555                   Jewellery    R$:999,00
# 4556                   Jewellery    R$:800,00
#
#                                               Descricao            Marca  \
# 0     Key Features of Alisha Solid Women's Cycling S...           Alisha
# 1     FabHomeDecor Fabric Double Sofa Bed (Finish Co...     FabHomeDecor
# 2     Key Features of AW Bellies Sandals Wedges Heel...               AW
# 3     Key Features of Alisha Solid Women's Cycling S...           Alisha
# 4     Specifications of Sicons All Purpose Arnica Do...           Sicons
# ...                                                 ...              ...
# 4552  Krg Enterprises Traditional Chirag Showpiece  ...  Krg Enterprises
# 4553  Vinnis Bella Bone Necklace - Buy Vinnis Bella ...           Vinnis
# 4554  Buy Rajo Raja The Buddha Of Music Artpiece Sho...        Rajo Raja
# 4555  Zakaah Jewels Amazing Quartz Sterling Silver P...    Zakaah Jewels
# 4556  VR Designers Plastic; Copper Necklace - Buy VR...     VR Designers
#
#                                                   Termo
# 0                                  Clothing: Confecções
# 1                                 Furniture: Mobiliário
# 2                                    Footwear: Calçados
# 3                                  Clothing: Confecções
# 4     Pet Supplies: Suprimentos para animais de esti...
# ...                                                 ...
# 4552  Home Decor & Festive Needs: Decoração e Necess...
# 4553                                   Jewellery: Jóias
# 4554  Home Decor & Festive Needs: Decoração e Necess...
# 4555                                   Jewellery: Jóias
# 4556                                   Jewellery: Jóias
#
# [4557 rows x 6 columns]

# %%
# expordando a base "tratada"
df.to_csv('Resultado.csv')
